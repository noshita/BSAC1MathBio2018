# %% [markdown]
# # MNIST ロジスティック回帰，SVM

# %%
from matplotlib import pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn import datasets, model_selection, svm, metrics

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# %%
mnist = datasets.fetch_mldata('MNIST original', data_home='data/download/')

print(type(mnist))
print(mnist.keys())
# Out:
# <class 'sklearn.utils.Bunch'>
# dict_keys(['DESCR', 'COL_NAMES', 'target', 'data'])

# %%
mnist_data = mnist.data / 255
mnist_label = mnist.target

print(mnist_data.shape)
print(mnist_label.shape)
# Out:
# (70000, 784)
# (70000,)

# %%
train_size = 6000
test_size = 10000
data_train, data_test, label_train, label_test = model_selection.train_test_split(mnist_data, mnist_label, test_size=test_size, train_size=train_size)

# %%
clf_logistic = LogisticRegression()
clf_logistic.fit(data_train, label_train)
pre_logistic = clf_logistic.predict(data_test)

ac_score_logistic = metrics.accuracy_score(label_test, pre_logistic)
print(ac_score_logistic)
# Out:
# 0.8981

# %%
clf = svm.SVC()
clf.fit(data_train, label_train)
pre = clf.predict(data_test)

ac_score = metrics.accuracy_score(label_test, pre)
print(ac_score)
# Out:
# 0.9126

# %%
co_mat = metrics.confusion_matrix(label_test, pre)
print(co_mat)
# Out:
# [[ 934    0    3    2    2   10    5    3    3    0]
#  [   0 1105    9    2    1    6    2    1    6    0]
#  [   7    8  929    5   15    4   25   22   23    5]
#  [   8    8   25  896    0   48    6   20   21   11]
#  [   3    3    3    0  882    1    6    4    3   48]
#  [   9   13    3   28    5  752   10    2    5    1]
#  [   8   10    7    0    3   20  923    0    3    0]
#  [   3   12   11    2   18    0    1  998    3   43]
#  [   6   36    9   31   12   29    9    7  828   18]
#  [  12   12    3   13   39    2    0   19   10  879]]
